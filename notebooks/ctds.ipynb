# %% [markdown]
# # Example for the CTD routines

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline

from IPython.core.display import display
import pathlib
BASE_DIR = pathlib.Path.cwd().parent
BASE_DIR
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib
# PosixPath('/home/mpim/m300660/PycharmProjects/mpim-icelab')

# %%
from mpim_icelab import ctd
ds = ctd.read_ctd(BASE_DIR / 'tests/test_ctd/data/sbe37sm-example-log.dat')
display(ds)
ds.salinity.plot()
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 150)
# Coordinates:
#   * time          (time) datetime64[ns] 2019-03-28T18:00:01 ... 2019-03-28T19...
# Data variables:
#     temperature   (time) float64 1.845 1.84 1.839 1.836 ... 1.29 1.284 1.282
#     conductivity  (time) float64 3.054 3.054 3.053 3.053 ... 3.006 3.006 3.006
#     pressure      (time) float64 0.568 0.572 0.566 0.564 ... 0.56 0.566 0.566
#     salinity      (time) float64 34.87 34.87 34.87 34.87 ... 34.88 34.89 34.89
